# %%
# Produce inputs from the elia (www.elia.be/en/grid-data/)
#
#import os
#import pandas as pd
#
#filename = "FILENAME"
#
#path = "./" + filename + "/"
#file_list = os.listdir(path)
#
#data = {}; data['Time'] = []; data['Power(MW)'] = []; data['Capacity(MWp)'] = []
#for i in range(len(file_list)):
#    data0 = pd.read_excel(path+file_list[i], skiprows=[0, 1, 2])
#    data['Time'] += list(data0['DateTime'])
#    data['Power(MW)'] += list(data0['Corrected Upscaled Measurement [MW]'])
#    data['Capacity(MWp)'] += list(data0['Monitored Capacity [MWp]'])
#data = pd.DataFrame(data)[['Time', 'Power(MW)', 'Capacity(MWp)']]
#
#data.to_csv(filename+".csv", index=False)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = [0, 1, 2, 3, 4, 5, 6, 7, 8]
y1 = [1.3, 0.3, 0.2, 0.1, 0, 0.1, 0.2, 1.2, 2.2]
x2 = [1, 2, 3, 4, 5, 6, 7, 8]
y2 = [3, 2, 1, 0, 1, 2, 3, 4]
x3 = [1, 2, 3, 4, 5, 6]
y3 = [3, 3, 3, 3, 3, 3]

figname = plt.figure()
plt.plot(x1, y1, 'r', linewidth=2.5, label=" ")
plt.plot(x2, y2, 'b--', linewidth=2.5, label=" ")
plt.fill_between(x3, y3, 0, facecolor="red", alpha=0.2)
plt.xlim([0,8])
plt.ylim([0,3])
plt.axis('off')
plt.show()

# Save Figures
#
#try:
#  from google.colab import files
#  figname.savefig('filename.pdf', bbox_inches='tight', format='pdf', dpi=1000)
#  files.download("filename.pdf")
#
#except:
#  figname.savefig('filename.pdf', bbox_inches='tight', format='pdf', dpi=1000)

# %%
fontsize1 = 13.5
fontsize2 = 11.5

s = 100*np.array([1.08504374, 1.1669298 , 1.00341572, 0.85738795, 0.88084403,
       0.88442114, 0.94331758, 1.01863175, 0.94807033, 0.77477963,
       0.8161409 , 0.76050217, 0.81598242, 0.79407998, 0.66795969,
       0.70807466, 0.66128057, 0.69610287, 0.74161079, 0.65283499,
       0.58505312, 0.57229861, 0.50164883, 0.36761907, 0.43789369,
       0.29833247, 0.22542453, 0.18484856, 0.16135782, 0.08554355,
       0.07462069, 0.05958455, 0.06398659, 0.05166728, 0.05061099,
       0.06716196, 0.06330781, 0.04757111, 0.07014575, 0.04812626,
       0.04742369, 0.04901897, 0.04143543, 0.04019158, 0.03586061,
       0.02780414, 0.03553024, 0.02483953, 0.02559124, 0.02236799,
       0.02616299, 0.03947645, 0.02900228, 0.02392976, 0.02368873,
       0.02565282, 0.03179777, 0.02446134, 0.02232573, 0.01781507,
       0.02170733, 0.02071426, 0.02316028, 0.02266645, 0.01626152,
       0.01820954, 0.01879078, 0.022231  , 0.02184914, 0.02046485,
       0.03785006, 0.02268705, 0.03084093, 0.0236599 , 0.02340872,
       0.02068489, 0.02287189, 0.02066446, 0.0222365 , 0.02413622,
       0.02435729, 0.02117551, 0.02073791, 0.02293271, 0.02927134,
       0.02192795, 0.02009846, 0.02030915, 0.02429303, 0.02110377,
       0.01843719, 0.02234132, 0.02223325, 0.02437027, 0.02418336,
       0.0395698 , 0.03040555, 0.02428795, 0.0256612 , 0.02534611])

w = 100*np.array([3.30973668, 0.50543405, 0.15667097, 0.08971393, 0.05824041,
       0.05237485, 0.04645546, 0.03442955, 0.03561596, 0.03261248,
       0.03123788, 0.03909022, 0.0399493 , 0.04371167, 0.03364666,
       0.03141504, 0.04158193, 0.03654223, 0.04094774, 0.03162518,
       0.04632165, 0.03675068, 0.03363105, 0.03517685, 0.03617578,
       0.03661222, 0.03133706, 0.03065915, 0.0582941 , 0.04114525,
       0.03261534, 0.03005798, 0.04065738, 0.04836853, 0.0339274 ,
       0.03880125, 0.03516368, 0.04205904, 0.02988169, 0.04504382,
       0.03705647, 0.04126474, 0.06904512, 0.04605317, 0.03798614,
       0.04814728, 0.03294867, 0.03377917, 0.03029889, 0.02832501,
       0.03413338, 0.03544909, 0.04311244, 0.02984156, 0.04311455,
       0.05402748, 0.04663702, 0.03388393, 0.03519386, 0.02979047,
       0.03238401, 0.03157803, 0.04430326, 0.04611478, 0.03611974,
       0.03988599, 0.03964444, 0.0333341 , 0.03264018, 0.03203599,
       0.0325248 , 0.03134069, 0.03044758, 0.02964506, 0.03264584,
       0.03007403, 0.03275276, 0.0313509 , 0.03354379, 0.03180427,
       0.02997998, 0.03171846, 0.03272281, 0.03178648, 0.0311956 ,
       0.03693748, 0.03667756, 0.03219669, 0.03884039, 0.03397166,
       0.03467229, 0.03388055, 0.03235572, 0.0385299 , 0.04005315,
       0.04353119, 0.03534037, 0.0483318 , 0.03853655, 0.03338929])

# %%
# Solar_PBE epsilon = 0.01, 0.1, ∞

ei = 100*np.array([0.44930812, 0.93246523, 1.33155705, 0.76294599, 0.8226853,
       1.21895071, 0.73700159, 0.35948774, 0.37808334, 0.69095805,
       0.2395741 , 0.83331798, 0.42049849, 0.21737338, 0.09639507,
       0.09260955, 0.11304199, 0.06756051, 0.0971043 , 0.09049264,
       0.11640956, 0.13733527, 0.05070732, 0.09145053, 0.05259735,
       0.16664603, 0.08993415, 0.13435915, 0.09679842, 0.05527548,
       0.03704981, 0.04155882, 0.06713386, 0.06139829, 0.05514069,
       0.05305346, 0.17413865, 0.14994712, 0.095779  , 0.04415322,
       0.14266006, 0.25599485, 0.04725216, 0.17788457, 0.0808875 ,
       0.03111537, 0.23073696, 0.05310286, 0.28653777, 0.09485999,
       0.0473658 , 0.16488455, 0.0805008 , 0.14971192, 0.24314962,
       0.06651516, 0.11739099, 0.08707485, 0.09038676, 0.22105541,
       0.18686313, 0.06816073, 0.01817811, 0.02734678, 0.08374376,
       0.04587779, 0.0733459 , 0.02491116, 0.02684635, 0.14123724,
       0.03186174, 0.09401631, 0.02633087, 0.05023305, 0.02384838,
       0.16994827, 0.18833365, 0.07482288, 0.02624947, 0.03414687,
       0.06519841, 0.10195439, 0.02394064, 0.06515197, 0.02938814,
       0.03181032, 0.03303731, 0.02661585, 0.11119687, 0.03644128,
       0.01649647, 0.02716911, 0.07401129, 0.08912455, 0.02915899,
       0.04307073, 0.02270595, 0.02367813, 0.05677629, 0.04217152])
e1 = 100*np.array([0.56941864, 1.00622211, 1.33154132, 1.14234165, 1.04350683,
       1.07743855, 1.0239984 , 0.79533861, 0.98931996, 0.64777758,
       0.56629161, 0.80820165, 0.33094121, 0.31796964, 0.2242214 ,
       0.10665246, 0.14974012, 0.07369071, 0.10681153, 0.16154647,
       0.1161493 , 0.05647067, 0.06411424, 0.03486801, 0.04152116,
       0.13712071, 0.04338857, 0.03860958, 0.03432474, 0.06179976,
       0.19332481, 0.07014961, 0.0711697 , 0.07708981, 0.04999571,
       0.03111006, 0.03593749, 0.03975974, 0.05490861, 0.04346742,
       0.03012767, 0.09935613, 0.03753551, 0.04603517, 0.02951249,
       0.0212418 , 0.06741047, 0.05061734, 0.04253679, 0.08551577,
       0.02268133, 0.01779946, 0.0676573 , 0.07158209, 0.06147872,
       0.0321972 , 0.13885583, 0.05532168, 0.05966406, 0.06526763,
       0.03015172, 0.09446631, 0.04258463, 0.10294588, 0.02978099,
       0.09134037, 0.05057878, 0.0229715 , 0.08012964, 0.08978926,
       0.13717307, 0.10822889, 0.06388897, 0.09182911, 0.04555674,
       0.04188451, 0.04991443, 0.02516716, 0.04693557, 0.02090821,
       0.08186879, 0.0459149 , 0.02848992, 0.07612319, 0.07275948,
       0.02398698, 0.01602445, 0.07640103, 0.10723753, 0.07960816,
       0.01673493, 0.01904199, 0.01762884, 0.04257455, 0.01439348,
       0.04013682, 0.07972783, 0.0477586 , 0.1285949 , 0.05247638])

fig_val_epsilon1 = plt.figure()
plt.plot(range(1,101), ei, 'r:', linewidth=1.5, label='ε=∞')
plt.plot(range(1,101), e1, 'g--', linewidth=1.5, label='ε=0.1')
plt.plot(range(1,101), s, 'b', linewidth=1.5, label='ε=0.01')
plt.xticks(fontsize = fontsize2)
plt.yticks(fontsize = fontsize2)
plt.xlabel("Episode", fontsize=fontsize1)
plt.ylabel("MAPE [%]", fontsize=fontsize1)
plt.xlim(1,100)
plt.ylim(0,135)
plt.grid(linestyle='--', linewidth=0.5)
plt.legend(fontsize=fontsize1, loc=1)
plt.show()

# %%
# Wind_Wallonie_Elia epsilon = 0.01, 0.1, ∞

ei = 100*np.array([1.15046137, 1.35815635, 0.69307279, 0.85249366, 0.983400656,
       0.54518155, 0.77977747, 0.75566474, 0.99948563, 0.86956616,
       0.74016753, 0.25735131, 0.15868179, 0.17557551, 0.13106155,
       0.11106665, 0.08873543, 0.0831086 , 0.06934869, 0.07239284,
       0.06289313, 0.05404124, 0.05663619, 0.04607939, 0.0404245 ,
       0.02874416, 0.03393947, 0.03743434, 0.03227642, 0.04938427,
       0.0336049 , 0.03312769, 0.02983424, 0.03537512, 0.04944096,
       0.03252452, 0.02967736, 0.0334909 , 0.02680204, 0.03837873,
       0.04072182, 0.04384581, 0.06924083, 0.23238704, 0.03934755,
       0.03233068, 0.03845793, 0.10542963, 0.0384225 , 0.04836348,
       0.03928582, 0.03394034, 0.03980885, 0.03311022, 0.03668274,
       0.03389833, 0.03300874, 0.02873403, 0.03555445, 0.03395718,
       0.03873619, 0.03316714, 0.03740341, 0.03284958, 0.23138694,
       0.03708415, 0.03083148, 0.05019851, 0.07677423, 0.03139695,
       0.03300538, 0.03231576, 0.04056918, 0.03480604, 0.0405305 ,
       0.04469019, 0.03150246, 0.03527052, 0.05220355, 0.03357355,
       0.02987788, 0.03148834, 0.03577153, 0.03102509, 0.03277208,
       0.0312581 , 0.03201895, 0.0477085 , 0.21347695, 0.03624272,
       0.04373803, 0.04101563, 0.03474826, 0.03327009, 0.31389409,
       0.05873892, 0.0340789 , 0.03612819, 0.03128603, 0.03491558])
e1 = 100*np.array([1.15488977, 1.19922707, 1.12961807, 1.09924015, 0.77903363,
       0.76276251, 0.65783806, 0.73557018, 0.55646207, 0.46765772,
       0.28703611, 0.31419098, 0.66357504, 0.35045231, 0.46538636,
       0.24201723, 0.46623361, 0.28115869, 0.33688996, 0.28925475,
       0.29881649, 0.35930802, 0.26757306, 0.11697192, 0.11144022,
       0.04000574, 0.04103513, 0.03837394, 0.03336301, 0.03559687,
       0.05580146, 0.04714727, 0.03677709, 0.03165642, 0.03291198,
       0.05333414, 0.03460581, 0.03042354, 0.03617119, 0.0363249 ,
       0.0310819 , 0.0424749 , 0.04106596, 0.04253929, 0.05754697,
       0.04814728, 0.03294867, 0.03377917, 0.03029889, 0.02832501,
       0.03413338, 0.03544909, 0.04311244, 0.02984156, 0.04311455,
       0.05402748, 0.04663702, 0.03388393, 0.03519386, 0.02979047,
       0.03238401, 0.03157803, 0.04430326, 0.04611478, 0.03611974,
       0.03988599, 0.03964444, 0.0333341 , 0.03264018, 0.03203599,
       0.0325248 , 0.03134069, 0.03044758, 0.02964506, 0.03264584,
       0.03007403, 0.03275276, 0.0313509 , 0.03354379, 0.03180427,
       0.02997998, 0.03171846, 0.03272281, 0.03178648, 0.0311956 ,
       0.03693748, 0.03667756, 0.03219669, 0.03884039, 0.03397166,
       0.03467229, 0.03388055, 0.03235572, 0.0385299 , 0.04005315,
       0.04353119, 0.03534037, 0.0483318 , 0.03853655, 0.03338929])

fig_val_epsilon2 = plt.figure()
plt.plot(range(1,101), ei, 'r:', linewidth=1.5, label='ε=∞')
plt.plot(range(1,101), e1, 'g--', linewidth=1.5, label='ε=0.01')
plt.plot(range(1,101), w, 'b', linewidth=1.5, label='ε=0.1')
plt.xticks(fontsize = fontsize2)
plt.yticks(fontsize = fontsize2)
plt.xlabel("Episode", fontsize=fontsize1)
plt.ylabel("MAPE [%]", fontsize=fontsize1)
plt.xlim(1,100)
plt.ylim(0,135)
plt.grid(linestyle='--', linewidth=0.5)
plt.legend(fontsize=fontsize1, loc=1)
plt.show()

# %%
# Solar_PBE gamma = 0, 0.5, 0.99

g0 = 100*np.array([1.02142783, 0.44043389, 0.36867354, 0.19273901, 0.19058887,
       0.14104061, 0.12441904, 0.15411248, 0.12360566, 0.22676861,
       0.12772408, 0.12015623, 0.19292688, 0.11896931, 0.17190889,
       0.20891449, 0.12294604, 0.11547326, 0.12798668, 0.12619727,
       0.10719889, 0.07828808, 0.11086021, 0.11234   , 0.15048432,
       0.07496902, 0.13572159, 0.15272852, 0.16130371, 0.12003352,
       0.08809128, 0.14433069, 0.0813878 , 0.12250596, 0.17789883,
       0.13275494, 0.08110965, 0.11294081, 0.19003886, 0.1130985 ,
       0.11487067, 0.12060563, 0.11118164, 0.09144578, 0.11533195,
       0.05574031, 0.12148934, 0.11712125, 0.0953745 , 0.09949016,
       0.10765908, 0.12354081, 0.09488126, 0.11690992, 0.12416016,
       0.06507518, 0.09059325, 0.11069565, 0.07866339, 0.06240623,
       0.15707528, 0.12371155, 0.11285661, 0.11249453, 0.0810066 ,
       0.0848748 , 0.08672326, 0.11163956, 0.09833795, 0.06982071,
       0.12610121, 0.08104407, 0.08362436, 0.09308295, 0.13013164,
       0.10019184, 0.11062432, 0.11929913, 0.17704379, 0.11442701,
       0.09839205, 0.10211829, 0.1604948 , 0.08944099, 0.12020504,
       0.15659567, 0.10931723, 0.12927159, 0.11424761, 0.10471686,
       0.11774461, 0.13409108, 0.14811475, 0.08745587, 0.12504645,
       0.07411823, 0.0882652 , 0.0748376 , 0.0785756 , 0.08110482])
g5 = 100*np.array([0.53295841, 0.43798362, 0.59474253, 0.11481269, 0.07559555,
       0.07038612, 0.09664039, 0.11352496, 0.08311358, 0.08638281,
       0.06119307, 0.10936234, 0.1127028 , 0.08376182, 0.08276456,
       0.06624661, 0.04948085, 0.11250918, 0.06038216, 0.10480936,
       0.10178391, 0.08545888, 0.12001539, 0.10427151, 0.08000988,
       0.15851062, 0.13562825, 0.12728981, 0.1378194 , 0.05224454,
       0.11104182, 0.09736675, 0.08558706, 0.09696018, 0.13276728,
       0.06087826, 0.06993196, 0.05459171, 0.11179034, 0.04627481,
       0.070304  , 0.11542006, 0.10778209, 0.1078672 , 0.03961418,
       0.07291825, 0.06744125, 0.04009419, 0.10962991, 0.07406783,
       0.08390911, 0.08959461, 0.07576058, 0.10361657, 0.09722862,
       0.0756929 , 0.11407802, 0.08615648, 0.08169138, 0.11165471,
       0.09948183, 0.10185213, 0.05931602, 0.07474247, 0.07634225,
       0.07238551, 0.0675342 , 0.05329005, 0.07374491, 0.13040636,
       0.06016048, 0.06029298, 0.07243557, 0.07274811, 0.09594919,
       0.0819964 , 0.10481351, 0.04333251, 0.06100391, 0.06349292,
       0.0897635 , 0.06503148, 0.07138456, 0.07963621, 0.07118965,
       0.06385643, 0.04827178, 0.06872122, 0.06711585, 0.08131284,
       0.06222049, 0.07916689, 0.07584994, 0.08493671, 0.09170708,
       0.07041483, 0.05867723, 0.06749565, 0.06880979, 0.06828896])

fig_val_gamma1 = plt.figure()
plt.plot(range(1,101), g0, 'r:', linewidth=1.5, label='γ=0')
plt.plot(range(1,101), g5, 'g--', linewidth=1.5, label='γ=0.5')
plt.plot(range(1,101), s, 'b', linewidth=1.5, label='γ=0.99')
plt.xticks(fontsize = fontsize2)
plt.yticks(fontsize = fontsize2)
plt.xlabel("Episode", fontsize=fontsize1)
plt.ylabel("MAPE [%]", fontsize=fontsize1)
plt.xlim(1,100)
plt.ylim(0,120)
plt.grid(linestyle='--', linewidth=0.5)
plt.legend(fontsize=fontsize1, loc=1)
plt.show()

# %%
# Wind_Wallonie_Elia gamma = 0, 0.5, 0.99

g0 = 100*np.array([1.19499468, 0.09605229, 0.06177909, 0.05659427, 0.04793495,
       0.08591061, 0.16978483, 0.05834903, 0.07311219, 0.04606133,
       0.05556375, 0.03688352, 0.03741274, 0.09668   , 0.04626775,
       0.07189538, 0.0490186 , 0.0459687 , 0.10518672, 0.04156813,
       0.06912389, 0.04116446, 0.10248413, 0.05740106, 0.1727842 ,
       0.1977856 , 0.13392291, 0.20527988, 0.05869229, 0.05752629,
       0.03829445, 0.1296728 , 0.09399878, 0.08862663, 0.142217  ,
       0.11390906, 0.21428033, 0.08782858, 0.10871863, 0.1151363 ,
       0.06383784, 0.0641807 , 0.12945844, 0.1331717 , 0.12324172,
       0.11961536, 0.15623663, 0.10903967, 0.09297763, 0.08898156,
       0.14111209, 0.10493779, 0.08909354, 0.11960806, 0.17237952,
       0.10862708, 0.13370468, 0.10721853, 0.11406112, 0.12084919,
       0.18967821, 0.10101547, 0.09219158, 0.11302845, 0.10578778,
       0.18607714, 0.17229727, 0.13646365, 0.12492416, 0.09693608,
       0.1562224 , 0.13723941, 0.0753325 , 0.10320046, 0.05414055,
       0.0989722 , 0.12854529, 0.08997476, 0.11804227, 0.15152217,
       0.1144114 , 0.13783342, 0.15018432, 0.07223024, 0.14595237,
       0.13584169, 0.15703323, 0.08912074, 0.13668209, 0.09655793,
       0.11360612, 0.08759179, 0.10777584, 0.17901475, 0.04761113,
       0.06454133, 0.11809141, 0.14026138, 0.11066527, 0.14754305])
g5 = 100*np.array([0.13086253, 0.05038954, 0.04243277, 0.03840077, 0.04084315,
       0.03936775, 0.05712612, 0.04651274, 0.07204126, 0.03795671,
       0.06617303, 0.09674774, 0.11822972, 0.05447025, 0.05477192,
       0.07325479, 0.06450725, 0.05039492, 0.1065195 , 0.07583532,
       0.08648984, 0.06782664, 0.08370575, 0.04447902, 0.10944239,
       0.0706312 , 0.092887  , 0.06815936, 0.10414426, 0.09271071,
       0.09510125, 0.06436025, 0.07139548, 0.08392066, 0.09200596,
       0.06940027, 0.10278744, 0.08834846, 0.11953879, 0.0834431 ,
       0.10675158, 0.06730385, 0.05898206, 0.07704299, 0.09090359,
       0.0711013 , 0.05830006, 0.05995175, 0.06475648, 0.13213749,
       0.05690968, 0.09212605, 0.05318053, 0.0715545 , 0.06857748,
       0.11820355, 0.10772041, 0.06785441, 0.11181407, 0.09741046,
       0.08784907, 0.12952153, 0.08044574, 0.06116647, 0.09754189,
       0.06166981, 0.07465869, 0.08710426, 0.07882481, 0.09662444,
       0.07022407, 0.0552717 , 0.09469807, 0.08918335, 0.10050449,
       0.09818818, 0.09812213, 0.06611185, 0.08801533, 0.08396132,
       0.06855096, 0.07191546, 0.09112302, 0.06294435, 0.0728056 ,
       0.06464055, 0.07514629, 0.08060434, 0.0942225 , 0.05699474,
       0.05240281, 0.08203722, 0.08409583, 0.07578695, 0.1124254 ,
       0.05840652, 0.05446472, 0.05129749, 0.08895028, 0.05532564])

fig_val_gamma2 = plt.figure()
plt.plot(range(1,101), g0, 'r:', linewidth=1.5, label='γ=0')
plt.plot(range(1,101), g5, 'g--', linewidth=1.5, label='γ=0.5')
plt.plot(range(1,101), w, 'b', linewidth=1.5, label='γ=0.99')
plt.xticks(fontsize = fontsize2)
plt.yticks(fontsize = fontsize2)
plt.xlabel("Episode", fontsize=fontsize1)
plt.ylabel("MAPE [%]", fontsize=fontsize1)
plt.xlim(1,100)
plt.ylim(0,120)
plt.grid(linestyle='--', linewidth=0.5)
plt.legend(fontsize=fontsize1, loc=1)
plt.show()

# %%
# Solar_PBE std = 0.05, 0.2, 0.1

d5 = 100*np.array([0.72874104, 0.85766888, 0.75416585, 0.68430077, 0.7864421,
       0.70768039, 0.76367028, 0.82253946, 0.88257605, 1.01453637,
       1.11531231, 1.17259942, 1.07056612, 0.95784438, 0.94140155,
       0.81391598, 0.67427663, 0.61816804, 0.68475753, 0.77250158,
       0.74378898, 0.68588548, 0.7685231 , 0.68520564, 0.61427404,
       0.58665839, 0.70656702, 0.5177984 , 0.53558394, 0.49240856,
       0.67118184, 0.60431904, 0.5865867 , 0.62368321, 0.57049607,
       0.51303736, 0.41825998, 0.46220067, 0.63688862, 0.56286552,
       0.40108129, 0.23588383, 0.39746112, 0.49125409, 0.26713276,
       0.14089013, 0.32869422, 0.31027337, 0.23784938, 0.15248138,
       0.11130632, 0.07005863, 0.05429152, 0.09895392, 0.07429993,
       0.0843428 , 0.06738321, 0.06560561, 0.05773153, 0.03423997,
       0.03223081, 0.03829555, 0.03878081, 0.02296255, 0.01990311,
       0.02897343, 0.02395997, 0.01635291, 0.02048747, 0.01607729,
       0.01714459, 0.0188226 , 0.01852856, 0.01921581, 0.01639269,
       0.01373087, 0.0161132 , 0.01588298, 0.01566548, 0.01428655,
       0.01456127, 0.01411709, 0.0194444 , 0.01466544, 0.0150766 ,
       0.0159919 , 0.01465368, 0.01587593, 0.01185414, 0.01304003,
       0.01493674, 0.0142489 , 0.01359408, 0.01380465, 0.01326503,
       0.01579753, 0.01535596, 0.01490384, 0.01481404, 0.01327201])
d2 = 100*np.array([0.96325833, 0.98163202, 0.74296874, 0.72686631, 0.50355679,
       0.82167981, 0.60638511, 0.88466162, 1.15856725, 1.08486739,
       0.40265603, 0.2331702 , 0.17229209, 0.21839782, 0.31320147,
       0.27602447, 0.3366434 , 0.28642837, 0.31204917, 0.27533453,
       0.270062  , 0.23167568, 0.17781484, 0.24822014, 0.32531695,
       0.30396351, 0.28832981, 0.13052546, 0.22075786, 0.1859094 ,
       0.10692407, 0.15518305, 0.21302012, 0.09897968, 0.12505044,
       0.09457639, 0.12934867, 0.17568322, 0.2106607 , 0.19819041,
       0.19328811, 0.13749502, 0.17850021, 0.25961354, 0.34257052,
       0.18034291, 0.16136375, 0.15166991, 0.1320579 , 0.20948062,
       0.19733371, 0.23492931, 0.17093025, 0.11646136, 0.11165229,
       0.21944103, 0.20940007, 0.13312639, 0.14216274, 0.08924339,
       0.13475013, 0.11452776, 0.14653496, 0.10117912, 0.10247504,
       0.11244798, 0.09914186, 0.13971156, 0.18924615, 0.16268998,
       0.14231852, 0.1472367 , 0.13112591, 0.07249372, 0.12518749,
       0.10625352, 0.10783229, 0.08451853, 0.09813472, 0.05924519,
       0.08579448, 0.12841001, 0.1119602 , 0.12434458, 0.09665172,
       0.13595286, 0.09962722, 0.05807543, 0.07609849, 0.10581077,
       0.0962292 , 0.07843044, 0.1079858 , 0.12491813, 0.11451346,
       0.06952429, 0.0970877 , 0.04644365, 0.05634951, 0.05329123])

fig_val_std1 = plt.figure()
plt.plot(range(1,101), d5, 'r:', linewidth=1.5, label='σ=0.05')
plt.plot(range(1,101), s, 'b', linewidth=1.5, label='σ=0.1')
plt.plot(range(1,101), d2, 'g--', linewidth=1.5, label='σ=0.2')
plt.xticks(fontsize = fontsize2)
plt.yticks(fontsize = fontsize2)
plt.xlabel("Episode", fontsize=fontsize1)
plt.ylabel("MAPE [%]", fontsize=fontsize1)
plt.xlim(1,100)
plt.ylim(0,120)
plt.grid(linestyle='--', linewidth=0.5)
plt.legend(fontsize=fontsize1, loc=1)
plt.show()

# %%
# Wind_Wallonie_Elia std = 0.05, 0.2, 0.1

d5 = 100*np.array([1.0369393 , 1.13769476, 1.06846885, 1.25100051, 0.88883765,
       0.95954316, 0.928211  , 0.67055703, 0.62227868, 0.68943506,
       0.5716119 , 0.64040495, 0.9063042 , 0.72753775, 0.87990302,
       0.76925859, 0.46342561, 0.59501245, 0.49180707, 0.58623829,
       0.46262057, 0.4194541 , 0.41967133, 0.23781345, 0.27933413,
       0.52960574, 0.40716939, 0.4372412 , 0.35179323, 0.33970436,
       0.19439111, 0.13721178, 0.11180572, 0.24524561, 0.10693371,
       0.08685463, 0.08620077, 0.08772279, 0.18120939, 0.16842236,
       0.08020797, 0.07023316, 0.06638949, 0.06323656, 0.0839746 ,
       0.06585105, 0.06108246, 0.07379199, 0.05179781, 0.04812338,
       0.04224154, 0.04245433, 0.03739772, 0.03530936, 0.02804865,
       0.02863502, 0.04346581, 0.05456211, 0.02926934, 0.02907456,
       0.03415247, 0.02936204, 0.0266494 , 0.03176027, 0.02630944,
       0.0282988 , 0.02779504, 0.02711859, 0.03089054, 0.02670021,
       0.0265776 , 0.02696329, 0.03593237, 0.02600364, 0.02721961,
       0.02880513, 0.02563435, 0.02551228, 0.02709764, 0.02843944,
       0.03982611, 0.02878927, 0.02962636, 0.02871851, 0.02757816,
       0.02549202, 0.02777717, 0.03224439, 0.02910984, 0.03053261,
       0.03047286, 0.02804266, 0.02802918, 0.02636386, 0.03226664,
       0.02880453, 0.03187666, 0.03599725, 0.03679094, 0.03141743])
d2 = 100*np.array([0.64360932, 0.73972281, 0.97523637, 0.85862944, 0.83875051,
       0.88164729, 0.90289229, 0.91900884, 0.92131775, 0.92192355,
       0.88981254, 0.87656766, 0.85521648, 0.85425807, 0.70816915,
       0.74164922, 0.62211872, 0.54012363, 0.63554226, 0.50806561,
       0.47396915, 0.45655677, 0.38305451, 0.42968733, 0.4821368 ,
       0.34367412, 0.41488516, 0.40951647, 0.32434465, 0.29407487,
       0.39061096, 0.40536302, 0.4316616 , 0.35404237, 0.2993432 ,
       0.36309038, 0.4154004 , 0.31717587, 0.35777103, 0.32475174,
       0.3536864 , 0.21898909, 0.18371008, 0.42556334, 0.2626639 ,
       0.22057799, 0.24547476, 0.38410167, 0.22453884, 0.27683674,
       0.20240647, 0.08358507, 0.27036803, 0.38602792, 0.23537079,
       0.30007518, 0.26333019, 0.3102267 , 0.24983158, 0.20721399,
       0.20694936, 0.14918918, 0.15542745, 0.24623816, 0.11883543,
       0.17604119, 0.20824127, 0.25480745, 0.15644072, 0.05954332,
       0.1632024 , 0.18447786, 0.23966846, 0.17037306, 0.26099221,
       0.16056928, 0.06345239, 0.1518847 , 0.13157584, 0.14413796,
       0.2050015 , 0.34135151, 0.166646  , 0.279034  , 0.21040757,
       0.0973699 , 0.09172484, 0.12963174, 0.18403077, 0.16122871,
       0.23109284, 0.20315131, 0.06296179, 0.15397847, 0.26525309,
       0.14264181, 0.10908351, 0.06284117, 0.1759942 , 0.18885221])

fig_val_std2 = plt.figure()
plt.plot(range(1,101), d5, 'r:', linewidth=1.5, label='σ=0.05')
plt.plot(range(1,101), w, 'b', linewidth=1.5, label='σ=0.1')
plt.plot(range(1,101), d2, 'g--', linewidth=1.5, label='σ=0.2')
plt.xticks(fontsize = fontsize2)
plt.yticks(fontsize = fontsize2)
plt.xlabel("Episode", fontsize=fontsize1)
plt.ylabel("MAPE [%]", fontsize=fontsize1)
plt.xlim(1,100)
plt.ylim(0,120)
plt.grid(linestyle='--', linewidth=0.5)
plt.legend(fontsize=fontsize1, loc=1)
plt.show()
